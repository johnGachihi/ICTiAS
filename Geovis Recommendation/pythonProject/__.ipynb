# %%
from recommender import recommend_visualisations
from util import VarIntent, Intents

# %%
recommend_visualisations(
    data="test_nigeria_water_points.geojson",
    
    # Simple example
    # variables=["water_type"],
    # rank=True,
    
    # Useful pattern
    variables=["water_type", "households_served"],
    filter=["water_type", "households_served"],
    rank=True,
    # intent=VarIntent("households_served", Intents.HIGH)
    
    # No useful pattern
    # variables=["water_type", "water_quantity"],
    # filter=["water_type", "water_quantity"],
    # rank=True,
)
# Out:
# Plotting Design2(encodings=[Encoding(variable='households_served', encoding='SIZE'), Encoding(variable='water_type', encoding='COLOR_HUE_C')])
# C:\Users\robot\Assignment_Workspace\ICTiAS\Geovis Recommendation\pythonProject\.venv\Lib\site-packages\geoplot\geoplot.py:248: UserWarning: Please specify "legend_var" explicitly when both "hue" and "scale" are specified. Defaulting to "legend_var='hue'".
#   warnings.warn(
# Plotting Design2(encodings=[Encoding(variable='households_served', encoding='SIZE'), Encoding(variable='water_type', encoding='SHAPE')])
# Plotting Design2(encodings=[Encoding(variable='households_served', encoding='COLOR_HUE'), Encoding(variable='water_type', encoding='SHAPE')])
# Plotting Design2(encodings=[Encoding(variable='households_served', encoding='COLOR_LIGHTNESS_H'), Encoding(variable='water_type', encoding='SHAPE')])
# ...
